# %%
import pandas as pd

# %%
chexpert = pd.read_csv("/home/harsh/Documents/fau/thesis/thesis-codebase/data/mimic_cxr/mimic-cxr-2.0.0-chexpert.csv")

# %%
negbio = pd.read_csv("/home/harsh/Documents/fau/thesis/thesis-codebase/data/mimic_cxr/mimic-cxr-2.0.0-negbio.csv")

# %%
chexpert.shape
# Out:
# (227827, 16)

# %%
chexpert.head()
# Out:
#    subject_id  study_id  Atelectasis  Cardiomegaly  Consolidation  Edema  \
# 0    10000032  50414267          NaN           NaN            NaN    NaN
# 1    10000032  53189527          NaN           NaN            NaN    NaN
# 2    10000032  53911762          NaN           NaN            NaN    NaN
# 3    10000032  56699142          NaN           NaN            NaN    NaN
# 4    10000764  57375967          NaN           NaN            1.0    NaN
#
#    Enlarged Cardiomediastinum  Fracture  Lung Lesion  Lung Opacity  \
# 0                         NaN       NaN          NaN           NaN
# 1                         NaN       NaN          NaN           NaN
# 2                         NaN       NaN          NaN           NaN
# 3                         NaN       NaN          NaN           NaN
# 4                         NaN       NaN          NaN           NaN
#
#    No Finding  Pleural Effusion  Pleural Other  Pneumonia  Pneumothorax  \
# ...

# %%
chexpert.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227827 entries, 0 to 227826
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   subject_id                  227827 non-null  int64
#  1   study_id                    227827 non-null  int64
#  2   Atelectasis                 57666 non-null   float64
#  3   Cardiomegaly                66799 non-null   float64
#  4   Consolidation               23076 non-null   float64
#  5   Edema                       65833 non-null   float64
#  6   Enlarged Cardiomediastinum  21837 non-null   float64
#  7   Fracture                    5831 non-null    float64
#  8   Lung Lesion                 8287 non-null    float64
#  9   Lung Opacity                58425 non-null   float64
#  10  No Finding                  75455 non-null   float64
#  11  Pleural Effusion            87272 non-null   float64
# ...

# %%
chexpert[chexpert.study_id == 57321224]
# Out:
#     subject_id  study_id  Atelectasis  Cardiomegaly  Consolidation  Edema  \
# 93    10002428  57321224          NaN           NaN            NaN    NaN
#
#     Enlarged Cardiomediastinum  Fracture  Lung Lesion  Lung Opacity  \
# 93                         NaN       NaN          NaN           NaN
#
#     No Finding  Pleural Effusion  Pleural Other  Pneumonia  Pneumothorax  \
# 93         NaN               NaN            NaN        NaN           NaN
#
#     Support Devices
# 93              NaN

# %%
negbio.shape
# Out:
# (227827, 16)

# %%
negbio[negbio.study_id == 57321224]
# Out:
#     subject_id  study_id  Atelectasis  Cardiomegaly  Consolidation  Edema  \
# 93    10002428  57321224          NaN           NaN            NaN    NaN
#
#     Enlarged Cardiomediastinum  Fracture  Lung Lesion  Lung Opacity  \
# 93                         NaN       NaN          NaN           NaN
#
#     No Finding  Pleural Effusion  Pleural Other  Pneumonia  Pneumothorax  \
# 93         1.0               NaN            NaN        NaN           NaN
#
#     Support Devices
# 93              NaN

# %%
metadata = pd.read_csv("/home/harsh/Documents/fau/thesis/thesis-codebase/data/mimic_cxr/mimic-cxr-2.0.0-metadata.csv")

# %%
metadata.shape
# Out:
# (377110, 12)

# %%
metadata.head()
# Out:
#                                        dicom_id  subject_id  study_id  \
# 0  02aa804e-bde0afdd-112c0b34-7bc16630-4e384014    10000032  50414267
# 1  174413ec-4ec4c1f7-34ea26b7-c5f994f8-79ef1962    10000032  50414267
# 2  2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab    10000032  53189527
# 3  e084de3b-be89b11e-20fe3f9f-9c8d8dfe-4cfd202c    10000032  53189527
# 4  68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714    10000032  53911762
#
#   PerformedProcedureStepDescription ViewPosition  Rows  Columns  StudyDate  \
# 0                CHEST (PA AND LAT)           PA  3056     2544   21800506
# 1                CHEST (PA AND LAT)      LATERAL  3056     2544   21800506
# 2                CHEST (PA AND LAT)           PA  3056     2544   21800626
# 3                CHEST (PA AND LAT)      LATERAL  3056     2544   21800626
# 4               CHEST (PORTABLE AP)           AP  2705     2539   21800723
#
#     StudyTime ProcedureCodeSequence_CodeMeaning ViewCodeSequence_CodeMeaning  \
# ...

# %%
len(metadata.dicom_id.unique())
# Out:
# 377110

# %%
metadata.ViewPosition.unique()
# Out:
# array(['PA', 'LATERAL', 'AP', 'LL', nan, 'LAO', 'RAO', 'AP AXIAL',
#        'SWIMMERS', 'PA LLD', 'AP LLD', 'XTABLE LATERAL', 'AP RLD',
#        'PA RLD', 'LPO'], dtype=object)

# %%
metadata.ViewPosition.value_counts()
# Out:
# ViewPosition
# AP                147173
# PA                 96161
# LATERAL            82853
# LL                 35133
# PA LLD                 4
# LAO                    3
# RAO                    3
# AP AXIAL               2
# AP LLD                 2
# XTABLE LATERAL         2
# AP RLD                 2
# SWIMMERS               1
# PA RLD                 1
# LPO                    1
# Name: count, dtype: int64

# %%
# Count non-NaN values for each row
non_na_per_row = negbio.drop(columns=["subject_id", "study_id"]).count(axis=1)
non_na_per_row
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         2
#          ..
# 227822    2
# 227823    1
# 227824    5
# 227825    2
# 227826    1
# Length: 227827, dtype: int64

# %%
# Get the total number of columns
total_columns = len(negbio.drop(columns=["subject_id", "study_id"]).columns)

# %%
len(negbio.columns)
# Out:
# 16

# %%
total_columns
# Out:
# 14

# %%
# Count how many rows have a non-NaN count equal to the total columns
complete_rows_count = (non_na_per_row == total_columns).sum()
